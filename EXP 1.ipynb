# %%
import matplotlib.pyplot as split
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\akars\OneDrive\Desktop\5th SEM\DATA VISUALIZATION, ANALYTICS\LAB\Online Sales Data.csv")
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
x = df["Date"]

# %%
x
# Out:
# 0      2024-01-01
# 1      2024-01-02
# 2      2024-01-03
# 3      2024-01-04
# 4      2024-01-05
#           ...
# 235    2024-08-23
# 236    2024-08-24
# 237    2024-08-25
# 238    2024-08-26
# 239    2024-08-27
# Name: Date, Length: 240, dtype: object

# %%
y = df["Total Revenue"].round(3)
y
# Out:
# 0      1999.98
# 1       499.99
# 2       209.97
# 3        63.96
# 4        89.99
#         ...
# 235     159.99
# 236     270.00
# 237      32.97
# 238      55.00
# 239      59.98
# Name: Total Revenue, Length: 240, dtype: float64

# %% [markdown]
# split.plot(x,y)

# %%
split.plot(x,y)
